# %% [markdown]
# # Convert Word (Transcript) to DataFrame
#
# Transcription using MS Word creates a format where timestamp and speaker are on one line, and the utterance is on the next. This notebook converts this format (from a Word docx file) to a CSV or Excel file by first converting it into a Pandas DataFrame first.

# %%
import docx2txt
import pandas as pd
from IPython.display import display, Markdown

# %% [markdown]
# ### Get relevant text from the Word Doc
# The Word document often contains some preamble, typically followed by the word `Transcript` after which the transcript begins. Test this assumption by printing the contents of the variable `text` below. If this is correct, then only extract the text _after_ the word 'Transcript'.

# %%
transcript_path = "data/mia-transcript.docx"
transcript = docx2txt.process(transcript_path)
# print the first 500 characters, just to check.
transcript[:500]
# Out:
# "T\n\nBoth. But you have to record everything.  \n\nM\n\nNice. I'm Mia. Nice to meet you. We know each other. This is Bas. Who Is I don't know What. \n\nB\n\nI'm doing something important.\n\nM\n\nOK whatever\n\nT\n\nDo you know any quiet places here at the faculty?\n\nM\n\nwe could do, we could get, like a meeting room and then go like we can get that meeting room over there.\n\nR\n\nIn the project room maybe? \n\nT\n\nOhh yeah, we can just steal one.\n\nM\n\nOh yes, we can check the project rooms. But I feel like those were alw"

# %% [markdown]
# ### Clean up the text
# A number of carriage returns will be in the text file. This is useful to split up the file into lines, so the code below does the following:
# 1. Splits the text into lines where a line is either a `timestamp, speaker` combo an `utterance`, or an empty line (in case of multiple successive carriage returns;
# 2. Removes all empty lines;
# 3. Replaces all non-breaking spaces (unicode: `\xa0`)
# 4. Splits the `'timestamp, speaker'` string combination into a list with `['timestamp', 'speaker']` in it.

# %%
transcript_list = transcript.split("\n")
transcript_list = [s.strip() for s in transcript_list if len(s.strip()) > 0]
transcript_list = [s.replace('\xa0',  ' ') for s in transcript_list]
transcript_list
# Out:
# ['T',
#  'Both. But you have to record everything.',
#  'M',
#  "Nice. I'm Mia. Nice to meet you. We know each other. This is Bas. Who Is I don't know What.",
#  'B',
#  "I'm doing something important.",
#  'M',
#  'OK whatever',
#  'T',
#  'Do you know any quiet places here at the faculty?',
#  'M',
#  'we could do, we could get, like a meeting room and then go like we can get that meeting room over there.',
#  'R',
#  'In the project room maybe?',
#  'T',
#  'Ohh yeah, we can just steal one.',
#  'M',
#  'Oh yes, we can check the project rooms. But I feel like those were always full.',
#  'T',
#  'I thought you were English.',
#  'M',
#  "I am but I'm learning Dutch.",
#  'R',
#  'Really?',
#  'M',
#  'Yeah. Are you Spanish? Yeah.',
#  'R',
#  'Yeah, really evident.',
#  'T',
#  'Were you the one who were posting those super views?',
#  'M',
#  'Ohh my gosh, yes.',
#  'T',
#  "I'm so upset that they're no longer there because someone complained.",
#  'M',
#  "I am very upset myself as well. I left. I left the chat. I'm done.",
#  'T',
#  'No, serious?',
#  'M',
#  'Yeah, I was, I left right afterwards, I was like bye.',
#  'T',
#  'Why he makes such a difficult case for something so simple?',
#  'M',
#  'I know !',
#  'T',
#  "Hey!  There's a project room, right here.",
#  'M',
#  "Perfect,  let's see if there's one there's one by the window.",
#  'T',
#  'Oh yes! Have you done AED here as well where you had like the window groups, which are way happier than the non window groups?',
#  'M',
#  'Yeah, I can imagine. Hmm.',
#  'T',
#  "I'm starting to have... I feel like these are quite popular. I think we're not going to get a window. hahah",
#  'M',
#  'No.',
#  'T',
#  'oh no, run, run.',
#  'R',
#  'This one.',
#  'M',
#  'Awesome',
#  'R',
#  'Are you recording all the time?',
#  'T',
#  'yes, they said we have to record right?',
#  'M',
#  'yes',
#  'R',
#  "Yeah, yeah, that that's actually... yeah?",
#  'M',
#  'Yeah, Did you guys know? Are you sitting in my seat?',
#  'B',
#  'No, I guess, maybe I am.',
#  'M',
#  'Did you? Did you guys know each other before this?',
#  'R',
#  'Yes, we were in a subject together, another elective.',
#  'M',
#  'Nice',
#  'R',
#  'You were in Generative AI right?',
#  'M',
#  'Yes! You were also in there?',
#  'R',
#  'Yeah',
#  'M',
#  'You took the exam yesterday as well?',
#  'R',
#  'Yeah, you didn’t ?',
#  'M',
#  "No, I did. I'm just doing that because I'm disappointed with the whole process of...",
#  'R',
#  "Yeah, I mean probably was like I did everything possible wrong to not do it because I didn't get enrolled at first, and It got postponed, then I forgot my ID, yesterday.",
#  'M',
#  'Ohh my gosh, yes I saw.',
#  'R',
#  'I did everything possible.',
#  'M',
#  "Yeah, but you ended up writing it. So that's good. Yeah, that's good.",
#  'R',
#  'Yeah, it was Mia right?',
#  'M',
#  'Yes, yes, Can you remind me your name one more time?',
#  'R',
#  'Rita.',
#  'M',
#  'Drita',
#  'R',
#  'Rita.',
#  'M',
#  'Rita. Rita. “ar”, “ai”, “ti”, “ei”',
#  'R',
#  'Yeah.',
#  'M',
#  'Okay, so, you haven’t even read this.',
#  'B',
#  'No.',
#  'M',
#  'You are. You are a little Spacey right now.',
#  'B',
#  'I am a bit frazzled.',
#  'M',
#  'I know, that was kind of like a long...',
#  'T',
#  "Frazzled what’s that kind of word?  I've never heard that one.",
#  'R',
#  'me neither.',
#  'M',
#  'like fried',
#  'B',
#  "Means you're sort of like confused. Overwhelmed a little bit, but I just. I had to do something annoying.",
#  'T',
#  "This morning I was like, oh fuck, oh fuck because I wasn't good at Dutch grammar and now I'm getting lectures on English grammar and... oh my God, no, this is going to be a tough course.",
#  'R',
#  'I really liked Spanish grammar but it doesn’t have to do anything with English.',
#  'M',
#  'Yeah.',
#  'B',
#  "Ok, Let's make something.",
#  'M',
#  'Yeah. Yeah.',
#  'B',
#  "3 concepts, choose the concept we want. Implement the term and concept. That's it. Make a video of the concept.",
#  'T',
#  'We could have a giant wall where we can post post- its.',
#  'M',
#  'I think we should make a 3D like, like, like, like a',
#  'B',
#  'The Eiffel Tower.',
#  'M',
#  "yeah, exactly. Like a giant, like tornado. You know, I feel like that's taking the easy way out by putting it on the wall.",
#  'T',
#  'Where else would you put it?',
#  'M',
#  'Like 3D, you make it on the...',
#  'B',
#  'On the. Table.',
#  'M',
#  'yeah product, yeah.',
#  'T',
#  'Ohh!  like that, OK. You have carboard here that we can steal?',
#  'M',
#  'Are we allowed to use other..?',
#  'B',
#  "Let's create process. We can decide ourselves, but I think we can, can we just use this to make something?",
#  'T',
#  'Do you know origami?',
#  'R',
#  'I know how to do a cube, cube with origami.',
#  'M',
#  "A cube? Oh, yes, that is cute. That's cute.",
#  'T',
#  'Well, that’s the fundamentals of IDE, right? designing a cube.',
#  'R',
#  'I think I remember right.',
#  'M',
#  'OK.',
#  'T',
#  'You can also create a pixel drawing with the...',
#  'R',
#  'Oh yeah!',
#  'M',
#  "That's so cute! But then we would have to, like, draw. We would have to. Yeah, that's a lot.",
#  'T',
#  "But we. Got. Black. So we've got 2. Colors.",
#  'R',
#  'You have to record also visuals?',
#  'T',
#  'yes.',
#  'B',
#  'We have to make a 2. Minute video at the end of our final concept.',
#  'R',
#  'Yeah, OK. But should we start recording already or not?',
#  'T',
#  "No, it's just final concept, right?",
#  'M',
#  'Yeah, I think we should start recording when we start making it.',
#  'B',
#  'are you recording?',
#  'T',
#  "I'm recording the audio right now so...",
#  'M',
#  "Like, right now we're discussing it says come up with at least three concepts discussed and choose one concept that you like. So I think that's fine to be audio and then as soon as we start implementing the chosen concept and constructing it, then we can video record it. Yes?",
#  'B',
#  'slay',
#  'M',
#  'wait, no slay yet, We haven’t come up with a concept',
#  'B',
#  'well it’s slay that we all know what we are doing here',
#  'M',
#  'I guess.',
#  'T',
#  "That's the start of a good project, right? Everybody on board on the same idea?",
#  'M',
#  'Yeah.',
#  'B',
#  'Mia?',
#  'M',
#  'what?',
#  'B',
#  "That's in the recording now.",
#  'M',
#  'OK.',
#  'T',
#  'everything you say will be and can be used against you.',
#  'M',
#  "OK. Why don't we all come up with an idea? And then we eliminate the worst ones. So we have 3, and then we eliminate the two worst ones. And then we have one.",
#  'R',
#  "Yeah, it's a process.",
#  'T',
#  'With post it notes.',
#  'B',
#  "Wait, I I feel like I've seen, like, epic stuff being done with.",
#  'M',
#  "There's definitely been epic stuff",
#  'T',
#  'Yeah, you can make like accordions like we can make like pseudo instruments with with post-it notes.',
#  'R',
#  'How did the post- its started? It was a mistake right? The invention of the post-it. It was like a mistake with glue.',
#  'M',
#  'yeah',
#  'R',
#  'like the original purpose was just...?',
#  'M',
#  'Basta!',
#  'B',
#  'I just wanna...',
#  'M',
#  'Look up post-it,  post-it invention. Or like whatever.',
#  'M',
#  "We could make like, no, that's too easy. Let's not make it too complicated either.",
#  'T',
#  "That's where, like the the that's the the edge sort of.",
#  'M',
#  'Yeah',
#  'T',
#  'It’s quite difficult to get it right in between.',
#  'M',
#  'yeah, oh that’s so cute!',
#  'B',
#  'whoah whoah wi whoah',
#  'T',
#  "What? That's cool.",
#  'R',
#  'thank you',
#  'B',
#  'see these people, they they use.',
#  'M',
#  "Ohh yeah, I see it. That's cool. That's really cool, actually. And that's 8.",
#  'T',
#  "You know what I also find a really nice concept. Just leaving, like, cute notes on the note posted notes is putting it in random places to make people happy. Like say on the toilet like you're awesome.",
#  'M',
#  "That's so cute. I love that idea.",
#  'T',
#  'And I think people would just let let them be and then just like put them at every mirror of the toilet or something?',
#  'M',
#  'I love that idea.',
#  'B',
#  'what?',
#  'M',
#  "I love that because I feel like a lot of people are gonna try to create something like, that's all. Like it's one thing with all the post notes in one place. But having it like like 100 posts...and I love that idea.",
#  'B',
#  'just hang them up here somewhere.',
#  'M',
#  'Like all the way around, everywhere around the faculty, with a nice note on it.',
#  'B',
#  "You're a legend.",
#  'T',
#  'On the printer, your project is amazing!',
#  'M',
#  "That's so cute, man.",
#  'B',
#  "That's a good idea.",
#  'M',
#  "That's a really good idea. And we can, like, film. We can, like film us putting them on. I love that idea.",
#  'T',
#  'So you could just do like this.',
#  'B',
#  'yeah, this is not going to be much of an interesting idea.',
#  'M',
#  "Not because also it's already, it’s ready, it's already on the Internet.",
#  'B',
#  'stealing an idea is also creativity.',
#  'R',
#  'So this is like inspiring post-it messages. This is more like a physical object.',
#  'B',
#  'Yeah. This is also like a physical object',
#  'M',
#  'And that can be like in the bathroom mirror. I love it. I vouch for it.',
#  'B',
#  "Yes. And then you said like your pennis It's looking really good, yeah.",
#  'T',
#  "That's so awesome. The urinal size doesn't matter.",
#  'M',
#  "So good. Oh my God, that's really good. That would be cool.",
#  'T',
#  "There's people looking angry at us from behind. They weren't too fond of us, but they got the windows. So.",
#  'M',
#  'yeah exactly.',
#  'T',
#  'But what kind of things would you say to someone on the toilet? On the mirror?',
#  'B',
#  "it does It doesn't smell that bad",
#  'M',
#  "don’t push too hard. You'll crack your butt.",
#  'B',
#  "Just funny notes. That's hilarious. Compliments and funny notes.",
#  'M',
#  "I love it. And funny notes. Yeah, that's, like the funny too.",
#  'T',
#  'weird facts?',
#  'M',
#  "No. OK, no. Let's stick to part like a people. Yeah, Max. Like that. Like, that's great.",
#  'B',
#  'Like 5 words alright so. Wait, we need 3 concepts.',
#  'T',
#  'Yeah. So that was one.',
#  'M',
#  'I mean, technically we did like, we shot some ideas. I said tornado. You said something , you said this cute stuff.',
#  'T',
#  'Pixel art.',
#  'M',
#  "Pixel art, Yes, we're spitting. We were spitting ideas.",
#  'T',
#  'Watch out for the connotation of those words, cause maybe the the the analyzing machine is gonna be like ohh spitting is negative.',
#  'M',
#  'Yeah, sublime genius.',
#  'T',
#  "Let's just keep all of those positive words in here.",
#  'B',
#  "It's an absolute work of sublime genius.",
#  'M',
#  "oh you've got to be joking.",
#  'B',
#  'You have got to be joking.',
#  'M',
#  "You're joking,",
#  'M',
#  'OK! So should we come up with More ideas? Or should we just go with this idea? I love this idea.',
#  'B',
#  "I feel like whatever we're going to come up with is going to be...",
#  'M',
#  'Dismissed.',
#  'T',
#  'Yeah, why not?',
#  'M',
#  "OK, let's come up with something then, and then dismiss it.",
#  'T',
#  "That's also one way of going about it. What could you do with post it notes that's surprising and effective in some way?",
#  'B',
#  'mmm',
#  'T',
#  'Just give them to random design students who are very frustrated to...see,  here, visualize your work.',
#  'M',
#  'We could like it, could be like a like a path. We could use them as a path, like a.',
#  'T',
#  'Escape room?',
#  'M',
#  'no. Literally.  Or like like, highlight an emergency exit with, like, a path of post-its and notes.',
#  'T',
#  "You know, like some sort of treasure map. But then like, they get subtle hints and at the end is there's, like, a little surprise.",
#  'M',
#  "Yeah. Yeah, that's so cute. OK, that's an idea. Let's just dismiss it, next.",
#  'B',
#  "You could, you could also do the compliment one but instead of compliments hints. There's like: go to the next toilet and then look underneath the...",
#  'M',
#  "Oh my God. And then there's another post. Yeah. And then what's there? Just a posted note.",
#  'B',
#  "and then you go all the way through and then it's like your hair looks cute and it’s like a bold guy.",
#  'M',
#  'So sad. Painful.',
#  'B',
#  'So like, I feel like the even the post note was... because we first wanted to just compliment and then we got to like funny things in the toilet?',
#  'M',
#  "That's also true",
#  'B',
#  "which is, I don't know if it's a whole new concept, but that idea of where you have like.",
#  'M',
#  "That's transformed.",
#  'B',
#  'You can use for many many many applications. You could do like, like cheating, like in the, in the bathroom if you might forget.',
#  'M',
#  'Oh my God.',
#  'T',
#  'I love. I love that so much. I recently went to a party and there was this one girl who lived whose house it was and she just had like, her whole study. Notes of like psychology on the toilet so she could read it while she was just doing her stuff and I was just sitting. I was just sitting there and looking at it. What ,what? This is so cool to read.',
#  'B',
#  'taking a shit',
#  'M',
#  'What are Oh, my God, Maddies.',
#  'B',
#  'Oh, yeah, hell yeah.',
#  'M',
#  'He got Canada, his girlfriend is from Canada.',
#  'B',
#  'Has he got these socks from girls?',
#  'M',
#  'he got Canadian socks.',
#  'T',
#  'Gotta represent the girlfriend.',
#  'M',
#  "they're actually quite cute. I like them. They're really nice.",
#  'B',
#  "And they're really tall, so you could they withstand cold",
#  'T',
#  'They are made for the British, not the.',
#  'B',
#  "Yeah. The other ones are Canadian animals. They're like a goose, a moose and a and A and a Beaver, all say. Sorry.",
#  'M',
#  "Sorry, sorry. OK. So OK, I think we've done enough.",
#  'B',
#  "To be honest, I do think, yeah, but I think we can combine multiple things. Let's not do the treasure hunt because that's going to be a whole lot of thinking. Which I can't do. I haven't explored my design intelligence yet. Interesting for the transcription. And then we..",
#  'M',
#  'can you pass me the post-it notes?',
#  'T',
#  'Of course.',
#  'B',
#  'my handwriting is is so is dreadful...',
#  'T',
#  'There you go, do you also want the pencil?',
#  'M',
#  "Thank you. I'm going to split this four ways.",
#  'B',
#  "My handwriting is so terrible it's not even.",
#  'R',
#  'sorry guys, I was sending an email.',
#  'T',
#  'you are getting enrolled?',
#  'R',
#  'yes otherwise I cannot see anything.',
#  'M',
#  'just be like.  Like, sorry, not you.',
#  'R',
#  'what? No I didn’t hear',
#  'M',
#  'he was just saying that his handwriting is so bad, but you can just ride it nicely.',
#  'T',
#  'You can also just draw hearts and cute emojis.',
#  'B',
#  'True. No, no, no. I think they have to. Like actually say something that has to do with the location of where you are. So I think when it comes to the toilet, we can make all kinds of nasty jokes. But like, yeah, genitals',
#  'T',
#  'hahah boobs.',
#  'B',
#  'those are not genitals technically speaking. Anyways, but then for the study places It would be like... these projects looking amazing man',
#  'R',
#  'like here in the project room.',
#  'B',
#  'Like here in the front room. Seats with one on the table.',
#  'T',
#  "It's going to be kind of strange to record in the toilet hanging up post it notes.",
#  'B',
#  "I don't think you're technically allowed.",
#  'R',
#  "Maybe we can put it like under the, under the cover, so you open it and then you see like ohh surprise! But that's gonna get...",
#  'T',
#  'removed',
#  'R',
#  'wet',
#  'B',
#  "It's gonna. Yeah. It's gonna be kind of gross. Yeah. Yeah. But we can also do it in the door. So when you're sitting on the toilet, in the door. So it's like...",
#  'R',
#  "Yeah, that's a really nice marketing strategy. I think every advertisement I've seen in the door has stuck more than anything else.",
#  'B',
#  'Yeah. We could also just promote our own Instagrams.',
#  'R',
#  'because you are forced to see',
#  'T',
#  "I'll. I'll work on the mirrors, I guess.",
#  'B',
#  'Yeah. And then, Mia. Do you have some writing ideas?',
#  'M',
#  'Yes, I do. Should we? OK, so how should we do this? should we go around and like, should we go individually and then right as we go shoot?',
#  'B',
#  "No. Maybe. Maybe it's better if we... two people take a lap around the uni and come up with ideas for kinds of messages per per location. And then two other people just start here writting with, like, what we already know, like the toilet.",
#  'T',
#  'OK, so the two persons who are going to go also have to go record.',
#  'R',
#  "Well, I mean in the exploration part it's not yet... I mean we can record already but it’s not...",
#  'T',
#  'You got to record your voice as well. Everything needs to be recorded I think',
#  'R',
#  'Ah, OK.',
#  'B',
#  "So maybe that's an idea, right?",
#  'T',
#  'Yeah.',
#  'B',
#  "So. I'll go and have a walk.Who join who's joining me?",
#  'R',
#  'I can join the walk.',
#  'M',
#  "Wait, I'm so confused.",
#  'B',
#  "two people stay here, they start writing about like the toilet ones we already know. So that's the mirror and in the toilet and above the urinal.",
#  'M',
#  "Okay, and we're just writing locations.",
#  'B',
#  'And then two other people just gonna walk around and do up inspiration from more kind of locations that we could do.',
#  'M',
#  'OK. So we so we write like so the people that are here write like like the location then like what can be like the vibe. Of the person.',
#  'B',
#  "Well, it's I think you shouldn't write it on the post it notes. No, you just have like a stack of toilet ones. Stack of study room ones...",
#  'M',
#  'Oh yeah, yeah.',
#  'B',
#  'One stack of. Whatever. And then two other people go around seeing what kind.',
#  'R',
#  'So should we define already which ones are already like toilet?',
#  'B',
#  'Yes I think the toilet. And then you maybe have to distinguish urinal, toilet like the the cubicle and the mirror where you wash your hands.',
#  'M',
#  "But, but don't you think that it's like more? It's easier. Like it's more feasible going like in pairs. And then as you go, you like, the ideas come to you as you go. So like, for example, you walk pass by the printer and you're like, oh, we can put something there and then film each other as we go.",
#  'R',
#  'yeah, we could go all together because if we have to record it anyway we can just like write..',
#  'B',
#  'we can easily do the whole thing. In like an hour.',
#  'M',
#  "Yeah, not even. Yeah. So, like, what? Yeah, let's just go all together. And then when someone sees something, then we...",
#  'B',
#  'Yeah, so, so you put your phone in your, yeah, in that pocket. And we take everything.',
#  'R',
#  'OK, so. And we are all only doing it in the design faculty, right?',
#  'B',
#  "Only in this, Well, let's let's start here.",
#  'T',
#  "So let's head to the printers, I guess.",
#  'M',
#  'Who wants to video record?',
#  'B',
#  'I can do it, It is better if I have large phone.',
#  'M',
#  "No, I'm saying, yeah, I know. I'm saying who can use their phone? I mean, I could. But I was saying I was running out of space.",
#  'T',
#  'I cannot record and and film at the same time.',
#  'M',
#  "Is this someone's belly cup?",
#  'T',
#  "Yes, but it's so dirty. I'll come pick it up later.",
#  'M',
#  "Ohh yeah, we're coming back here anyways, right? Yeah.",
#  'T',
#  "But don't leave your computer otherwise it might get stolen.",
#  'B',
#  'Can you help with this?',
#  'T',
#  'Yes, of course.',
#  'B',
#  'Take it. Yeah, yeah.',
#  'R',
#  'Okay so should I start recording already?',
#  'M',
#  'Yes.',
#  'R',
#  'Horizontally, right?',
#  'M',
#  'Oh, yeah. I think too small. It will be easier.',
#  'R',
#  'Does it have to be a long video or I mean, Doing like a small...like small... sketch.',
#  'M',
#  'I think do small. It will be easier to edit. Later.',
#  'B',
#  'Do you have good handwriting?',
#  'M',
#  'you could also writte.',
#  'B',
#  "I only have a pen in my hand right now. OK, so it's like. These damn printers, huh? Could never work.",
#  'T',
#  'Maybe we should put something into like scanning machine like where you put your paper.',
#  'M',
#  "Ohh no, because then they're gonna scan and then they're gonna waste their own money.",
#  'T',
#  "You can also put it here where they have to scan their cards so they have to look at it. That's what Idid",
#  'M',
#  'Your project slays.',
#  'T',
#  'Then, playful for sure. See it.',
#  'B',
#  'we can hang one in the project room saying like clever People working here.',
#  'M',
#  "Ohh that's cute.",
#  'T',
#  'Yeah, see the animals.',
#  'R',
#  'In the coffee machine guys? Would you put something? like a lot of people goes to the coffee machine, right?',
#  'M',
#  "That's also true,  he's posted something on the coffee machine too.",
#  'T',
#  "I am. I'm not. Afraid of posting things on the coffee maker?",
#  'B',
#  'Coffee Machine is good.',
#  'T',
#  "I got, I have one. Wait. Give me one second. I'm not an ID student.",
#  'M',
#  "Oh my God. I've got such a good idea.",
#  'T',
#  "Well, I ran out of space, but that's fine there you go.",
#  'T',
#  'You can do anything you set your mind to.',
#  'B',
#  'I Hope you get there.',
#  'M',
#  'That’s so bad. Is it raining?',
#  'T',
#  "I think that was God saying that we shouldn't do this.",
#  'M',
#  "No, wait, no. Let's write. Let's say",
#  'B',
#  'Or something like a Lightning McQueen.',
#  'R',
#  'what?',
#  'T',
#  'And imagine sitting on the toilet and hearing all. Of this.',
#  'M',
#  'OK. Should we write something?',
#  'B',
#  "It's very spacious in there.",
#  'M',
#  'It is quite spacious in there.',
#  'T',
#  'Might take a nap in there.',
#  'M',
#  "I think we're going just for the humorous route now.",
#  'B',
#  'Yeah, well, hope you feel better.',
#  'M',
#  'Are we writing that?',
#  'B',
#  "Maybe we shouldn't do this. Because they're gonna backtrack this to the. Course and then the. Guys are gonna..",
#  'T',
#  "I'm gonna hang this in in the in the.Toilet.",
#  'R',
#  'OK, what should we...',
#  'T',
#  "Oh, don't forget to record your audio. OK, so we have this.",
#  'T',
#  'maybe you should use English cause otherwise, yeah, yeah, yeah.',
#  'B',
#  'My handwriting is freaking bad. And then here in the in the.',
#  'T',
#  'do it in the, the, the most shameful one.',
#  'B',
#  "Better. That's a fucking hog.",
#  'T',
#  'Damn bro.',
#  'T',
#  'And what more?',
#  'B',
#  'Kind of smells or something',
#  'T',
#  "We're doing a project.",
#  'B',
#  'We are Writting post its and Leaving messages for people that are like...can you make a smiley face?',
#  'T',
#  "First one. Let's go out of the next toilet. I think we've already populated this toilet with too many posted notes now.",
#  'B',
#  'Yeah.',
#  'T',
#  'Thank you.',
#  'M',
#  "Oh, my God, that's really good.Yeah. Like we just. Right, push and then pull it.Tell them as well.",
#  'R',
#  'To put something in the doors because I get confused with what to do.',
#  'M',
#  'You just say push and pull. As English speaker, I agree.',
#  'T',
#  'As a native dutch speaker.',
#  'M',
#  'Wait, but we should do it on a. Different door cause this is automatic.',
#  'T',
#  'All we can do, like boring on the lecture hall.',
#  'B',
#  'Or just put our names next to like the. Names over there and post it notes.',
#  'M',
#  "That's good. Ohh my gosh, that's. Really good. Let's do that.",
#  'T',
#  "I don't think they're gonna be quite happy with.",
#  'B',
#  "but I don't care.",
#  'T',
#  'We should put one in the photo studio saying no nudes here, no nudes.',
#  'M',
#  'Why do they do nude photography in there ?',
#  'T',
#  "Yeah, I I don't want anything harmful on my recording. If you don't mind.",
#  'B',
#  'Some people were like, oh, OK.',
#  'R',
#  "Because I think that red buttons are really. Likely to be pushed like I think. I don't know why they make them so ...",
#  'T',
#  "Is that a new trash can over there. What's that?",
#  'B',
#  'Our names here.',
#  'T',
#  "But isn't that forgetting the original plot of the? I don't know.",
#  'M',
#  'Yeah, I was watching that too.',
#  'R',
#  'What is the purpose actually?',
#  'T',
#  'Making people happy and now we are ...',
#  'B',
#  'Do you think the boring on this door is a Good one?',
#  'M',
#  'maybe we can draw a cell phone or we can write a cell phone.',
#  'R',
#  "You're late. It's also a good one. You are waiting outside. If you are seeing the door it’s because you're waiting.",
#  'M',
#  "Oh yeah, that's true.",
#  'M',
#  'Oh Nice like like if anyone puts it on silence. Nice. Cute.',
#  'T',
#  "There's always this one person.",
#  'M',
#  'I feel like. We need to do things that people actually look at though cause no one really looks at these things.',
#  'T',
#  'On the toilet, they will',
#  'M',
#  "but yeah, exactly. That's why we.",
#  'T',
#  'I have one for the next toilet. Give me one second.',
#  'R',
#  "We yeah. Shoul we put something like, for example, if we put something like in the platform like from here would be people intrigued to know what's in there? Do you think?.",
#  'M',
#  'I don’t get it.',
#  'T',
#  'At the workspace we can put stuff on the computer screens.',
#  'R',
#  "Here for example but in the platform and then like people from here might be like I want to see what's written there.",
#  'M',
#  'Yeah. This is far though.',
#  'R',
#  'Yeah, something just silly. Can you read me?',
#  'M',
#  "That's cute. Can you read me like? That it's sweet.",
#  'R',
#  "The coffee machine. We didn't. Put anything in the coffee machine, yeah.",
#  'T',
#  "Yeah, I'm used to putting stuff on coffee makers.",
#  'B',
#  'I think we should do something with the lockers.',
#  'T',
#  "Don't forget to lock. Don't get your computer stolen.",
#  'M',
#  'Yeah, I was thinking to say. Yeah, lock your computer away.',
#  'T',
#  'Hide your kids. Hide your wife.',
#  'M',
#  'If you see a Laptop laying around. We should put a post it on it.',
#  'T',
#  "It's gonna be quite tough because it's quite calm and ID today.",
#  'M',
#  'Yeah.',
#  'T',
#  'So there was this dilemma. Let me think. What was it again? I forgot. Ohh no, I’ll have to look it up. Oh we are busy for half an hour.',
#  'R',
#  'What is that?',
#  'M',
#  'no idea.',
#  'R',
#  'It also says like treat yourself well.',
#  'M',
#  'addict.',
#  'T',
#  "Caffeine is the modern is the the person's fuel or something? Caffeine is my gasoline.",
#  'M',
#  "That's cute caffeine.",
#  'T',
#  'Does any of you want coffee? Because I have free card.',
#  'R',
#  "I don't have a cup, but it's fine, I don’t want to abbuse",
#  'T',
#  'You. You don’t want what? I have 500 coffees a day.',
#  'R',
#  'Yeah. But like gasoline, at some point is. Too much. OK. Can we put there happy plant?',
#  'M',
#  'Happy plant.',
#  'T',
#  'We can just put a smiley on the plant somewhere.',
#  'M',
#  'Something like that. Oh my god, Where did that come from?',
#  'T',
#  'Come from. I want to hang this above one of the urinals.',
#  'M',
#  'that’s so funny.',
#  'R',
#  'I think you should have recorded it.',
#  'M',
#  "It's real. Oh, my God it is.",
#  'R',
#  'Yeah.',
#  'M',
#  'Water me.',
#  'T',
#  'I am thirsty.  I love your handwriting, by the way.',
#  'M',
#  "It's not very clean and.",
#  'T',
#  "No, but it's messy, but it's still readable at the same time. It's not those block letters like the blocks which are very simple to write and read but they don't they lack any personality.",
#  'M',
#  'Yeah.',
#  'R',
#  "I thought that we could, now it's not there, but like that we could maybe make like a smiley face or something common.",
#  'T',
#  'Something in a rotating door! Put put, put like eyes above the hands',
#  'R',
#  'Be patient.',
#  'M',
#  "Yeah, that's nice. OK let's do that.",
#  'T',
#  'You can put like little googly eyes above the hands and then they will be.',
#  'R',
#  'We think we can put something here. Wait for your turn or something.',
#  'M',
#  "that's nice. Or be patient then, like, yeah. This one you can film as it goes past. Wait, I'm going to put it on, and then you're gonna Have to wait for it to come there.",
#  'T',
#  'Is it gonna stick?',
#  'M',
#  "I think so. Let's see. OK, wait.",
#  'M',
#  "It's still there.Here it comes.",
#  'B',
#  "Could we do  like “I'm getting busy” in the middle?",
#  'M',
#  'Record it, record it, record it.',
#  'R',
#  'ah',
#  'M',
#  "Nice. I'm getting.",
#  'T',
#  'You spin me right round, baby, right round.',
#  'B',
#  'This is a case of absolute sublime genius.',
#  'T',
#  'The elevators. Yeah.',
#  'R',
#  "Where are the elevators? I've never used them.",
#  'T',
#  "You've never used them?",
#  'B',
#  "Let's go to the coffee first. But yeah.",
#  'T',
#  'Which coffee maker are we going?',
#  'B',
#  'the expensive coffee maker',
#  'T',
#  'to that one, yeah.',
#  'R',
#  'OK. You can tell this is expensive.',
#  'M',
#  'Oh, God. Oh my God.',
#  'B',
#  'Someone got banked.',
#  'M',
#  'Someone got banked.Remember your your savings.',
#  'T',
#  'The 24th is still far away.',
#  'M',
#  "Don't forget to rate me.",
#  'B',
#  'Should we do here something like joke about leftovers? Someone cooked too much',
#  'M',
#  'Can you really eat 4 day old leftovers?',
#  'T',
#  "You don't microwave that. That's most of the times, not advised.",
#  'B',
#  'Can we do like who even gets this?',
#  'T',
#  'I know a couple of people.',
#  'B',
#  'My handwriting sucks so bad.',
#  'M',
#  "Guys, we we've ditched, we've ditched the. OK, wait, record me saying this.",
#  'M',
#  "okay record me saying this. We've ditched being nice and now it's just humour.",
#  'T',
#  "It's still the general vibe, right? It's about bringing happiness to the general IDE public. Did you hear the comment of that guy after I put that posted note on there? You said, yeah, that's true. After I put water of the gods.",
#  'M',
#  'Yeah.',
#  'R',
#  'I like that. I like that.',
#  'R',
#  'Those handlers seem like they run out of budget.',
#  'T',
#  "Yes. Well, they've got a MacBook, so they have plenty of budgets.",
#  'R',
#  'Yeah, but the handlers look like they run out of money.',
#  'T',
#  'Oh the handlers.',
#  'M',
#  "So what I think we should do now is we should just take photos, so I like. I think we've got the whole vibe of like writing it down and walking around and now then we can kind of make like the compilation.",
#  'R',
#  "Yeah, I think it's better because it’s too much",
#  'T',
#  "We can edit it in. Yeah, it's quite easy to edit just short videos.",
#  'M',
#  'Yeah. Yeah, exactly. We can even make like a collage of them and then put that collage in the video.',
#  'T',
#  "Can we put like a very, very... so like put a song under it, which it just doesn't fit at all.",
#  'M',
#  'Yes, yes. Slipping through my fingers. Like so, like marriage, Christmas Carol.',
#  'T',
#  'Some Hard Rock or something. Just just get no, just just ask like AI to generate a Hard Rock song about putting posted notes in ID to make people happy and then put that under there.',
#  'M',
#  "Yes, that's so good.",
#  'R',
#  "We can already use the Christmas song we're already in November. Have you seen all the memes of Mariah Carey defrosting?",
#  'B',
#  'We have to go to the the Coca-Cola machines I guess like cookies and Coca-Cola or whatever.',
#  'R',
#  "We can go there. Yeah, I've never been.",
#  'T',
#  'Which one do you? Do you mean next to the?',
#  'M',
#  'the Vending machine!',
#  'T',
#  "Let's go to the one here in the corner.",
#  'B',
#  'let’s go to the one over there and then it say something about like I love diabetes.',
#  'T',
#  "Count your calories. No, that's not making people happy. That's making them sad.",
#  'B',
#  "“You needed this” I don't know something.",
#  'T',
#  'We we should put a post it note, bring back the sexy super conversations.',
#  'M',
#  'Yeah. Yeah. Yep, Yep, Yep.',
#  'T',
#  "It feels like a sign of protest. I do bet it's going to get photographed and put in a group as well.",
#  'T',
#  "It's a zesty emoji as well. I can also do it for you. Incognito. Or yeah, it feels good. Just put it there.",
#  'T',
#  'Just put it here, OK?',
#  'M',
#  "It's perfect, so visible.",
#  'T',
#  "We should go over there. Let's also go into the conversation, but.",
#  'M',
#  'I hope it does',
#  'T',
#  "Just put blank spaces everywhere. Are you Taylor Swift fan? Because you're a blank space.",
#  'M',
#  'Oh my God.',
#  'T',
#  'You should just put like these ads, huh? The cleaners hate us.',
#  'T',
#  "Should We put one on the Dean's door.",
#  'M',
#  "Who's that? Where?",
#  'T',
#  "it's on the 3rd floor.",
#  'M',
#  'Oh my god',
#  'T',
#  'Put something funny on this door. The boss of IDE very dumb.',
#  'B',
#  'Also, we have to do one on the elevator',
#  'T',
#  'Yes. I think our our, our coaches are going to be very fond of this idea.',
#  'B',
#  'This is convenient.',
#  'T',
#  'Have you seen this?  look so you can put in your deposit and then I donated to charity',
#  'B',
#  "It's amazing.",
#  'M',
#  'It’s not that an option on everything?',
#  'B',
#  'It’s just here not in the supermarkets.You can get a backfired Tiki.',
#  'T',
#  'Or you can donate it to charity.',
#  'B',
#  "It's the very two very viable and good options. Anyway, let's go to the elevator and then from the elevator to the Deans office.",
#  'T',
#  "Who's gonna? Put in the elevators?",
#  'B',
#  'Or we can do it here “you are here”. On the map.',
#  'M',
#  "Oh, you are? That's fun.",
#  'B',
#  "So that's here.",
#  ...]

# %%
print("Remove last item if it is incomplete.")
print('--------------------------- LAST 4 LINES ---------------------------')
for t in transcript_list[-4:] :
    print(t)
print('-------------------------------- END -------------------------------')

# Uncomment and re-run this cell if the last line is found to be incomplete
# if type(transcript_list[-1]) == list :
    # transcript_list.pop()
# Out:
# Remove last item if it is incomplete.
# --------------------------- LAST 4 LINES ---------------------------
# T
# Yes
# M
# I think we should stop that.
# -------------------------------- END -------------------------------

# %% [markdown]
# ### Convert into DataFrame
# Conver the list with successive items being `['timestamp', 'speaker]` and `'utterance'` items into a DataFrame

# %%
transcript_triad = []
for ind, line in enumerate(transcript_list) :
    if ind % 2 == 0 and ind+1 < len(transcript_list):
        # these are speaker/timestamp lines
        if line[0].isdigit() :
            # the start is a timestamp
            timestamp = line.split(' ')[0]
            speaker = ' '.join(line.split(' ')[1:])
            utterance = transcript_list[ind+1]
        else :
        # The line contains speaker but not timestamps 
            timestamp = ''
            speaker = line
            if len(line.split(' ')) > 2 :
                print("*****************************************")
                print("Problem found!")
                print(transcript_list[ind-3:ind+1])
                print(ind)
                print("*****************************************")
                break
            utterance = transcript_list[ind+1]
        turn_data = { 'timestamp' : timestamp,
                      'speaker'   : speaker,
                      'utterance' : utterance
                    }
        transcript_triad.append(turn_data)

# %%
# print(transcript_triad)
df = pd.DataFrame(transcript_triad)
df.sample(5)
# Out:
#     timestamp speaker                                          utterance
# 318                 M                     It is quite spacious in there.
# 299                 M                                   Ohh that's cute.
# 549                 B  Well, it's sort of funny because it's what eve...
# 451                 T  Yes. Well, they've got a MacBook, so they have...
# 47                  M                            Ohh my gosh, yes I saw.

# %% [markdown]
# ### Save DataFrame
# Because this involves text which can have punctuations including commas and semicolons, a CSV file is not recommended. Instead, save it as an excel file.

# %%
excel_name = transcript_path.split(".docx")[0] + ".xlsx"
df.to_excel(excel_name)
print("File saved to:", excel_name)
# Out:
# File saved to: data/mia-transcript.xlsx
