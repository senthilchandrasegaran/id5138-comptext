# %% [markdown]
# # Convert Word (Transcript) to DataFrame
#
# Transcription using MS Word creates a format where timestamp and speaker are on one line, and the utterance is on the next. This notebook converts this format (from a Word docx file) to a CSV or Excel file by first converting it into a Pandas DataFrame first.

# %%
import docx2txt
import pandas as pd
from IPython.display import display, Markdown

# %% [markdown]
# ### Get relevant text from the Word Doc
# The Word document often contains some preamble, typically followed by the word `Transcript` after which the transcript begins. Test this assumption by printing the contents of the variable `text` below. If this is correct, then only extract the text _after_ the word 'Transcript'.

# %%
transcript_path = "data/xavier-transcript.docx"
transcript = docx2txt.process(transcript_path)
# print the first 500 characters, just to check.
transcript[:500]
# Out:
# "00:00:00 Stan\n\nStarting the recording right now. \n\n00:00:03 Stan\n\nDoes everybody give consent? (general laugh)\n\n00:00:05 Xavier\n\nNo, now we have an excuse.\n\n00:00:12 Xavier\n\nI mean even that is going to get analysed.\n\n00:00:15 Stan\n\nYep (laugh) (..) All right\n\n00:00:20 Xavier\n\nIt's an (.) It's an interesting assignment.\n\n00:00:21 Rueben\n\nI guess I need a pen.\n\n00:00:22 Xavier\n\nYep.\n\n00:00:24 Xavier\n\nYeah, we might need. I mean, first, I don't know if we need the (..), I just need a pen and a pap"

# %% [markdown]
# ### Clean up the text
# A number of carriage returns will be in the text file. This is useful to split up the file into lines, so the code below does the following:
# 1. Splits the text into lines where a line is either a `timestamp, speaker` combo an `utterance`, or an empty line (in case of multiple successive carriage returns;
# 2. Removes all empty lines;
# 3. Replaces all non-breaking spaces (unicode: `\xa0`)
# 4. Splits the `'timestamp, speaker'` string combination into a list with `['timestamp', 'speaker']` in it.

# %%
transcript_list = transcript.split("\n")
transcript_list = [s.strip() for s in transcript_list if len(s.strip()) > 0]
transcript_list = [s.replace('\xa0',  ' ') for s in transcript_list]
transcript_list
# Out:
# ['00:00:00 Stan',
#  'Starting the recording right now.',
#  '00:00:03 Stan',
#  'Does everybody give consent? (general laugh)',
#  '00:00:05 Xavier',
#  'No, now we have an excuse.',
#  '00:00:12 Xavier',
#  'I mean even that is going to get analysed.',
#  '00:00:15 Stan',
#  'Yep (laugh) (..) All right',
#  '00:00:20 Xavier',
#  "It's an (.) It's an interesting assignment.",
#  '00:00:21 Rueben',
#  'I guess I need a pen.',
#  '00:00:22 Xavier',
#  'Yep.',
#  '00:00:24 Xavier',
#  "Yeah, we might need. I mean, first, I don't know if we need the (..), I just need a pen and a paper or something to right on to try and think and understand what what we're meant to do with this. (Laughter)",
#  '00:00:34 Xavier',
#  'Cause I am confused.',
#  '00:00:37 Julia',
#  'So I brought candy, if you want it.',
#  '00:00:40 Xavier',
#  'It’s food for the soul',
#  '00:00:42 Stan',
#  "It's been years since I tried on of these.",
#  '00:00:50 Xavier',
#  'This course is not what I expected it to be, I have to say.',
#  '00:00:53 Stan',
#  'In the good way or in a bad way?',
#  '00:00:55 Xavier',
#  "I don't know yet, and it's surprisingly.",
#  '00:00:57 Stan',
#  'Be careful (general laugh)',
#  '00:00:59 Xavier',
#  "In a surprising way. No, not necessarily bad, but I mean, I don't know. I I realised when I was reading the course manual that it wasn't what I expected it to be. And then again, I was like, but what did I actually expect it to be and I wasn't sure about that either so.",
#  '00:01:16 Stan',
#  'I honestly forgot I chose this elective right before we started.',
#  '00:01:21 Stan',
#  "But now I'm actually quite (.) Quite happy I chose this.",
#  '00:01:25 Julia',
#  'Yeah same',
#  '00:01:27 Stan',
#  "I guess it's definitely different than the other electives.",
#  '00:01:31 Xavier',
#  "Yeah, (..) It feels more, like, I mean, I'm used to IPD electives. It doesn't feel like an IPD elective now.",
#  '00:01:38 Stan',
#  'No definitely not',
#  '00:01:41 Julia',
#  "It's a bit of a research right, because I don't think it's DFI or SPD either.",
#  '00:01:43 Stan',
#  "Yeah. (.) It's something completely different.",
#  '00:01:50 Xavier (general laugh)',
#  'I mean, maybe we should start with presenting ourselves.',
#  '00:01:53 Xavier',
#  "Again, but not not just the names. Like what we like doing, and maybe cuz if we're trying to come up with a (.) I feel like a. (..) Yeah, try to find what direction we might want to go in, we might want to express what we're interested in and what we're used to doing.",
#  '00:02:08 Stan',
#  'Yeah, sure.',
#  '00:02:09 Julia',
#  'Sure.',
#  '00:02:09 Xavier',
#  'I can start.',
#  '00:02:11 Xavier',
#  "So I'm Xavier. I'm an IPD student. I also did a bachelor in mechanical engineering, so I'm a lot more product oriented, and technical stuff.",
#  '00:02:23 Xavier',
#  "And all of this design methods and things is, I'd say still relatively new to me. So yeah, that's it. And I don't know, post-its for me are usually just bookmarkers. So yeah.",
#  '00:02:37 Julia',
#  'So, and what? What excites you the most about this specific course?',
#  '00:02:45 Xavier',
#  "Well, initially I thought it was the AI part. I like machine learning also, so I'm, I'm quite curious to see what we do with that, but also just.",
#  '00:02:54 Xavier',
#  "Yeah, I find it interesting to delve more into the design methods. I know that not everyone loved DTM, but I really appreciated the the the concept of just exploring methods and trying to understand a bit better what I'm meant to do as a designer. Basically so. (.)",
#  '00:03:10 Xavier',
#  "I feel like that's probably kind of why I picked it.",
#  '00:03:12 Stan',
#  'Nice.',
#  '00:03:14 Julia',
#  'Cool.',
#  '00:03:15 Stan',
#  "Who's next?",
#  '00:03:17 Rueben',
#  'Sure, I’m Rueben',
#  '00:03:18 Xavier',
#  'Hello Rueben (Laughter)',
#  '00:03:19 Rueben',
#  "I’m SPD,  I did my bachelor in Eindhoven, industrial design as well. Ah, I kind of picked this course because I think I'm just subconsciously kind of staying away from AI stuff. So I purposely pick something that's more related to it.",
#  '00:03:24 Stan',
#  'Nice',
#  '00:03:36 Rueben',
#  "Yeah, that's was one of my motivations for this.",
#  '00:03:39 Julia',
#  'Yeah, cool.',
#  '00:03:41 Stan',
#  'Cool.',
#  '00:03:42',
#  '(Confusion)',
#  '00:03:42 Rueben',
#  'Right now, but you can.',
#  '00:03:46 Julia',
#  "Yeah, I'm Julia SPD students, second year. Actually, after DTM I was a bit like should I do a PhD like that? That was like the first time that I.",
#  '00:03:54 General',
#  'Wow.',
#  '00:03:57 Julia',
#  "Only a thought of because I don't want to.",
#  '00:03:58 Xavier',
#  'I was like I don’t want to do a Phd',
#  '00:04:01 Julia',
#  "Yeah, I definitely know that I don't want to do like the PhD, but actually the, (.) all the theory behind how we as designers (.) uhm do the things that we do, I'm quite interested in it.",
#  '00:04:13 Julia',
#  "And I didn't actually linked that this course was actually also because with Sentyl and with Peter that it was like an extension of it, but it's actually exciting.",
#  '00:04:24 Julia',
#  "Because I think on a daily basis, I'm also quite aware of how people behave and why they do what they do. So yeah, it's going to be interesting.",
#  '00:04:31 Stan',
#  'Also the psychological aspects.',
#  '00:04:33 Julia',
#  'Yeah, exactly. And then also nice that this course is also a way to quantify it a bit or to not only say, oh, you do it like this, but also really count it and link it back to like other literature, etcetera.',
#  '00:04:48 Julia',
#  'Uhm (..)',
#  '00:04:51 Julia',
#  "Yeah. And for me, maybe it's always interesting with these kinds of exercises we just talk about it and just see where we're going and and not that I don't how do you say I don't really need to reach a goal. I just want to have fun and see what it where it goes.",
#  '00:05:07 Stan',
#  'Nice on that, we agree.',
#  '00:05:10 Stan',
#  "Well, I'm Stan. I'm an SPD and IPD student. People still ask me why and don't really have an answer myself. (general laughs)",
#  '00:05:18 Stan',
#  'But I enjoy both.',
#  '00:05:21 Stan',
#  "Uhm (.) Generally my interests are also in those two areas. I really like technical aspect, but I feel like IPD is often a bit too technical and doesn't really ask the good, the right questions and SPD Is very much asking the right questions, but isn't really doing anything practical with it. So those two fill in each other's.",
#  '00:05:38 Julia',
#  'Hmm.',
#  '00:05:40 Stan',
#  "Yeah, the pieces missing pieces. So. So that's nice. And for this course, I'm mostly interested also in the like the application. So more of writing the Python scripts and using it within AI models to really come up with useful things, not necessarily the analysis per se, because I already did that in SPD research and it wasn't much (unintelligible) and part. And next to that I'm also just interested in having a lot of fun and seeing where this ends",
#  '00:06:09 Stan',
#  "That's it.",
#  '00:06:12 Julia',
#  'Cool.',
#  '00:06:12 Rueben',
#  'Nice',
#  '00:06:13 Xavier',
#  'Very different profiles.',
#  '00:06:16 Julia',
#  'One of the interesting things is that they really state something quite factual, like the classic note that is made of 100 individual.',
#  '00:06:24 Xavier',
#  'Should we count them? (general laughs)',
#  '00:06:25 Julia',
#  "No, please don't.",
#  '00:06:27 Stan',
#  'Let me just do that.',
#  '00:06:29 Xavier',
#  'Should we? We can measure them though.',
#  '00:06:30 Xavier',
#  "They actually 76 by 76. If they're not, then we say we can't do it anymore.",
#  '00:06:36 Stan',
#  "Yeah, I don't think we don’t have to the assignment then right?",
#  '00:06:41 Xavier',
#  'Fuck. They are 76 by 76, I tried.',
#  '00:06:49 Stan',
#  "Maybe it's also interesting to just have some initial ideas of things that you (..) would like to do with the Post-its, or do you already have?",
#  '00:06:58 Xavier',
#  'I have no ideas right now.',
#  '00:06:59 Stan',
#  "It's yeah. OK. Because what direction?",
#  '00:07:01 Xavier',
#  'We could do a drawing.',
#  '00:07:02',
#  'Yeah, maybe. Do we want a direction? Do we want to have something very like, systematic or more artsy or more? (.) Which route do you guys want to take? Do you already have a gut feeling about this.',
#  '00:07:14 Rueben',
#  'I mean, because you were saying drawing, I was thinking like puzzle as well (.) so maybe similar to like how we finished the sentence, we finished like a drawing or something.',
#  '00:07:25 Stan',
#  'Uh, yeah.',
#  '00:07:27 Xavier',
#  "I'm I'm thinking the I mean for me the apart from bookmarking with Post-its.",
#  '00:07:33 Xavier',
#  'I feel like.',
#  '00:07:33 Xavier',
#  'The the use of Post-its is just being able to move things around.',
#  '00:07:38 Xavier',
#  "I feel like that's the main advantage of using a post it rather than just putting it on paper. Is that like this idea can be paired with this idea so.",
#  '00:07:47 Xavier',
#  'Maybe word association or sketches or just a mishmash.',
#  '00:07:52 Xavier',
#  "Of (.) yeah, like a creative session where we just try to like we have a theme and then we try to come up with different parts of the thing. I have no idea where would this would go. And then we just try to group them together. I don't know to try and create new concepts or new designs or new methods.",
#  '00:08:09 Xavier',
#  "I don't know.",
#  '00:08:09 Stan',
#  "That's interesting.",
#  '00:08:11 Xavier',
#  'But I like the idea of having. (.) That in the end.',
#  '00:08:14 Xavier',
#  "Whatever we've done on the post-its, we can then move the post-its around to try and maybe group what's happened on the table.",
#  '00:08:20 Stan',
#  'Hmm',
#  '00:08:22 Xavier',
#  "Just not sure what we put on the post-its and what we'd be grouping.",
#  '00:08:26 Xavier',
#  "But I like the idea of being able to, and so that might mean. Then it's a bit more free flowing and less structured, cuz the other way would be just structuring them in a line, but I feel like you can.",
#  '00:08:38 Xavier',
#  'Do that on paper.',
#  '00:08:40 Stan',
#  "Yeah, that's interesting. I was thinking more towards a more artsy direction,",
#  '00:08:45 Xavier',
#  'OK',
#  '00:08:46 Stan',
#  "but I really like the idea of,  like introducing movement in some kind of way, because that's definitely something you can do with post-its, and that's cool.",
#  '00:08:54 Julia',
#  "I also thought of post-its. It's it's like a a way of finding things back because in your, also with the bookmark,",
#  '00:09:01 Xavier',
#  'Yeah.',
#  '00:09:01 Julia',
#  "it's representative for for something. So maybe something to do with that or we can just make a big square out of it, I don't know.",
#  '00:09:09 Stan',
#  "That that's actually something I don't know how I came up with this idea, and maybe you think.",
#  '00:09:14 Stan',
#  "It's very simple but.",
#  '00:09:15 Stan',
#  'I was thinking about something of a a post combining puzzle.',
#  '00:09:19',
#  'With.',
#  '00:09:21 Stan',
#  "Your memory, so brain mind maybe creating like a huge brain that's at the same time. It's like a like a line puzzle, right. Like you have an end, start and end and you need to draw a line. So you have all the movements and the like terms in your brain and you find the flow through the brain.",
#  '00:09:42 Stan',
#  "(.) So (unintelligeble) how to draw blurring, I don't know.",
#  '00:09:45 Xavier',
#  "That's fine, it doesn't look.",
#  '00:09:46 Xavier',
#  'Like, oh, do you take sketching classes. (general laugh)',
#  '00:09:49 Stan',
#  'Perhaps like these kind of things. And then you have like a start? (..) and an end.',
#  '00:09:57 Xavier',
#  'A reconfigurable brain puzzle.',
#  '00:09:59 Stan',
#  'Yeah, that would be cool. And then you, like, use the post-itsto find a route, route and come to a conclusion or something.',
#  '00:10:06 Julia',
#  'And why would you need te post-its for it and not something else?',
#  '00:10:09 Xavier',
#  'Well, because if you do that with post-its. Then I could decide where I could switch around the start and the end.',
#  '00:10:14 Stan',
#  'Ohhh',
#  '00:10:16 Xavier',
#  "You could move everything around and make a very confusing thing. Maybe an unsolvable problem puzzle, but that's not our problem.",
#  '00:10:22 Stan',
#  'Yeah, true.',
#  '00:10:24 Xavier',
#  "But yeah, if if all of these is different posts and you're just moving around, we could have a giant grid.",
#  '00:10:29 Xavier',
#  "And then you just move the post-its around and see what happens, I guess. See if that's even possible, I don't know.",
#  '00:10:37 Rueben',
#  'Or you just change to start and end for different place.',
#  '00:10:40 Stan',
#  'Do you know the the game (dutch name) with like the moving walls. So then you think you were going in the right direction and then suddenly a wall changes and you can’t kind of get through anymore. You need to go another route that kind of simulates the thinking process.',
#  '00:10:56 Julia',
#  'It also reminds me of the game (dutch name).',
#  '00:10:59 Stan',
#  'Yes, yes.',
#  '00:11:00 Julia',
#  "It's a game where you have you play it with multiple players and then you have cards of like it's a mining game. So you have the gold diggers and the the, the the saboteur.",
#  '00:11:10 Xavier',
#  "Yeah, but same thing in French, so we're fine.",
#  '00:11:12 Julia',
#  "OK. And then maybe if I'm the saboteur, then I will block the passage. But you guys want to find the gold, and then you have to put cards on it. (unintelligible)",
#  '00:11:25 Xavier',
#  'Yeah.',
#  '00:11:26 Stan',
#  "But that's just one idea. So we don't have to get fixated on it.",
#  '00:11:28 SXavier',
#  "That's I mean.",
#  '00:11:29 Xavier',
#  'No, but I mean they say 3 concepts that could be one.',
#  '00:11:32 Xavier',
#  'Of the concepts we could use.',
#  '00:11:33 Xavier',
#  'Post-its for',
#  '00:11:34 Julia',
#  'We need 3 concepts?',
#  '00:11:35 Xavier',
#  'Well, I mean it says 3 and then pick one and start doing it but it says come up with at least three at least. Sorry, not three. At least three concepts.',
#  '00:11:46 Stan',
#  'I can think of a couple more',
#  '00:11:46 Julia',
#  'OK, OK. So one of the maze concept which when we can we can.',
#  '00:11:54 Xavier',
#  'Maze brain',
#  '00:11:54 Julia',
#  "That's all right. Yeah, we can do this. The first one I was. I'm also thinking of like what other properties of it we have 100,  it’s squared.",
#  '00:12:03 Xavier',
#  "Apparently we have 100 we can count them, so we don't know.",
#  '00:12:05 Julia',
#  'It sticks, so I also like just like, what if we stick it on a person?',
#  '00:12:12 Rueben',
#  'Ohh.',
#  '00:12:13 Julia',
#  "I don't know what happens and then we're going to trace it. But then what happens next? I don't know.",
#  '00:12:16 Stan',
#  "All this funny like the, you know, the complement things like writing complements or something or someone that somebody with all the post-its just folks around IDE having post-its that's interesting, yeah.",
#  '00:12:31 Julia',
#  'Maybe we can focus a bit on the sticky parts and then come up with something.',
#  '00:12:34 Xavier',
#  'Yeah. post-it compliments where you give the compliment to someone by sticking the post-it on them and then everyone else can see that they are like that.',
#  '00:12:43 Xavier',
#  'You know, like creative and you just stick it on someone. And now that everyone that passes next to the person know that that person is creative.',
#  '00:12:51 Stan',
#  "Or, place Post-its in places people won't expect them, like on surfaces that people don't expect.",
#  '00:12:57 Xavier',
#  'Yeah, they open a cabinet and.',
#  '00:12:58 Xavier',
#  "They're like what? What is that doing there?",
#  '00:13:01 Stan',
#  "They're everywhere.",
#  '00:13:03 Xavier',
#  "Yeah, kind of like a positive notes. You just write positive notes on the post-it and then just start pasting them everywhere so that that to cheer someone in their day, they open the cabinet and it just says have a good day. You're like.",
#  '00:13:16 Stan',
#  'OK. Do we know where Sentyl’s office is?',
#  '00:13:20 Xavier',
#  'Flood his his office with a (..).',
#  '00:13:24 Xavier',
#  'Yeah, I mean, yeah.',
#  '00:13:24 Stan',
#  'Compliments of course.',
#  '00:13:27 Julia',
#  "It's annoying that we only have one colour because yeah, for me I also always use it as like a in a systemic way like also how they propose it here we can do like a product process system, engage with a particular environment or tell.",
#  '00:13:41 Julia',
#  'A story.',
#  '00:13:41 Xavier',
#  "But maybe, maybe that's why we wanted a single color.",
#  '00:13:44 Xavier',
#  "Maybe it's going to force us to be creative with how we use it?",
#  '00:13:45 Julia',
#  'Yeah, true.',
#  '00:13:47 Stan',
#  'Did they say that you can only use one color?',
#  '00:13:49 Rueben',
#  'No, no.',
#  '00:13:50 Xavier',
#  'OK. We just have one colour.',
#  '00:13:51 Stan',
#  'We can buy more.',
#  '00:13:52 Xavier',
#  'I have more in my backpack.',
#  '00:13:53 Stan',
#  'There you go.',
#  '00:13:58 Xavier',
#  "I have yellow ones. It it makes 2 colours. It's not a big stretch, but it's at least more than one.",
#  '00:14:00 Rueben',
#  'You could also do more like 3D’sque like origami direction.',
#  '00:14:07 Stan',
#  'Oh, nice, yeah.',
#  '00:14:09 Rueben',
#  'So to create something with sticky parts and then create something.',
#  '00:14:12 Stan',
#  "I really like your thinking because I didn't think about movements, and for me these notes are always 2D. So you're thinking in 3D. That's also very interesting, yeah.",
#  '00:14:23 Stan',
#  'Movement in 3D.',
#  '00:14:26 Xavier',
#  'And stickiness.',
#  '00:14:26 Stan',
#  'And stickiness.',
#  '00:14:28 Stan',
#  'You can definitely do something with that. (...)',
#  '00:14:34 Stan',
#  'So when it comes to stickiness, we have.',
#  '00:14:37 Stan',
#  "Putting it on, someone putting it in places people don't expect.",
#  '00:14:42 Xavier',
#  "Do you have any other ideas? Because it's your idea, this stickiness. So maybe you had a a thought in your mind about what you could do with it?",
#  '00:14:49 Julia',
#  'No, I was just thinking of putting it on people and that you see that people are belonging to the same category, yeah.',
#  '00:14:57 Stan',
#  'Oh.',
#  '00:14:58 Julia',
#  "Or it's also like the name like, yeah.",
#  '00:15:01 Xavier',
#  "A label. I don't know how I feel about that. (general laughs)",
#  '00:15:04 Xavier',
#  'Labelling people.',
#  '00:15:07 Xavier',
#  'Could go very good or very bad.',
#  '00:15:10 Julia',
#  "Yeah, it's it's a way of like maybe just ask a person like, what do you want to share today with people? And then you do write it down and you put it on, something like that.",
#  '00:15:18 Stan',
#  'Oh.',
#  '00:15:20 Stan',
#  "Yeah, that's interesting.",
#  '00:15:26 Xavier',
#  'I like the (..) that feels more like a (..) a one time thing, I really like the concept of just something that can continually be evolved and like reused in a way. So like the sticky notes that you just stick everywhere, you can just continue. Like if you find it you can just move it somewhere else and stick it somewhere else.',
#  '00:15:48 Xavier',
#  'So kind of like a game of just like positive comments.',
#  '00:15:51 Xavier',
#  "And I'm going to like, let someone else enjoying, bysticking it somewhere else in the and so it's just like you continually continue to discover new things because, like, you stuck it somewhere, but now someone just found it and stuck it somewhere else. And so they keep moving around.",
#  '00:16:06 Xavier',
#  "At some point, they're going to not stick anymore, which this might be a problem but.",
#  '00:16:11 Xavier',
#  'I like the idea of them.',
#  '00:16:11 Julia',
#  'Say it like that. Then I another idea I have is that we can make different shapes out of it so that we can just fold together or make like a like a triangle kind of shape and that we just give it to people or put it in a place where they can puzzle.',
#  '00:16:28 Stan',
#  'Like puzzle in what sense?',
#  '00:16:29 Julia',
#  'Yeah. So because just make a shape.',
#  '00:16:33 Julia',
#  "It doesn't matter if you do it like this and and then you just put it on the plate and then people just can can sit there and have a break, make a puzzle, make a shape and then someone new comes in and make something different out of it.",
#  '00:16:44 Julia',
#  'Because what would be an application of this?',
#  '00:16:47 Stan',
#  "I'm just. I'm going to write all these ideas down.",
#  '00:16:50 Julia',
#  'We can also do it in his.',
#  '00:16:52 Stan',
#  "Yeah, so that's fine. OK.",
#  '00:16:53 Xavier',
#  'Go ahead.',
#  '00:16:57 Julia',
#  'Because I like the way how you say, reuse it and also different people can then use it.',
#  '00:17:02 Xavier',
#  'Yeah, it could be a giant post-it puzzle. It kind of goes back to our brain again, because in a way it the brain was a bit of a. But yeah, I like the idea of.',
#  '00:17:10 Julia',
#  'And then should it be like for prototyping or should it be what is specific application of your idea?',
#  '00:17:18 Rueben',
#  'For team building stuff, right, they use lego’s and stuff like that to kind of prime questions and then for example like how do you see your?',
#  '00:17:27 Rueben',
#  'Group dynamic build something and then they build something with Legos to represent that kind of dynamic.',
#  '00:17:35 Rueben',
#  "So is that what you're thinking like?",
#  '00:17:37 Julia',
#  "I don't know. I was. I'm just thinking out loud.",
#  '00:17:39 Rueben',
#  'It could be so that build something that you already have questions for them that are a bit more abstract, but ask them to build it with the possible pieces.',
#  '00:17:54 Xavier',
#  'That could be interesting.',
#  '00:17:58 Xavier',
#  "Yeah, I'm. I'm trying to see if there's any way to. Yeah. Really have the reuse aspect of.",
#  '00:18:05 Julia',
#  "I think I like to. It's more reusable if you like, don't write anything on it, right? Just leave them blank. But the shape doesn't really mater.",
#  '00:18:16 Julia',
#  "Or I think people, if we want people to reuse it and it's should be as interpretable for me as for you for instance, that we maybe should not.",
#  '00:18:24 Xavier',
#  'Yeah.',
#  '00:18:25 Julia',
#  'Do that or we can do 50/50.',
#  '00:18:27 Stan',
#  'Yeah, you could also just if if you go the confluence route, just shape it into a heart or something. If you give it to someone that just that says enough already, right?',
#  '00:18:33 Julia',
#  'MHM.',
#  '00:18:38 Stan',
#  'And then maybe write down it like pass this on to someone else and then just film them and see what they do. (...)',
#  '00:18:52 Stan',
#  'So anyone have a preference.',
#  '00:18:54 Rueben',
#  'OK, so which ones exactly?',
#  '00:18:55 Xavier',
#  'Know this is still very vague.',
#  '00:18:58 Julia',
#  'We can also use it to make like a wall art. Just something. Make a statement out of out of something?',
#  '00:19:04 Xavier',
#  'Yeah.',
#  '00:19:10 Julia',
#  "On the coffee corner or something, I don't.",
#  '00:19:13 Xavier',
#  'You can make. You could definitely make art out of it.',
#  '00:19:20 Xavier',
#  'What is, (.) Okay',
#  '00:19:22 Xavier',
#  'Concretely, what are they asking us to do? Because it it just feels so vague.',
#  '00:19:28 Julia',
#  "It's interesting.",
#  '00:19:28 Xavier',
#  "If you're post-it, you can create a product or process and system, engage with a particular environment, or even tell a story. Yeah. So it's basically whatever you want.",
#  '00:19:37 Julia',
#  'Yeah, I liked it about it, but.',
#  '00:19:41 Julia',
#  'No',
#  '00:19:46 Stan',
#  "Yeah, it's, it's literally come up with ideas, choose one, implement it. That's all.",
#  '00:19:52 Julia',
#  "We could also even sometimes they you can stick it together, right. And it's like a harmonica. And then you can put it downstairs and then.",
#  '00:20:00 Stan',
#  'Thinking I really like the slinky.',
#  '00:20:00 Xavier',
#  'A post-it slinky.',
#  '00:20:02 Stan',
#  'I really like the slinky. (general laughs)',
#  '00:20:06 Xavier',
#  'You could also use the you have the story books, the one where you just the flip books.',
#  '00:20:08 Rueben',
#  'The yeah.',
#  '00:20:13 Julia',
#  "Ohh that's nice.",
#  '00:20:13 Xavier',
#  'Where you just do this and then you just have a story that.',
#  '00:20:15 Julia',
#  'Yeah, I like that.',
#  '00:20:17 Xavier',
#  'And then you could.',
#  '00:20:19 Xavier',
#  "Technically, because there's post-its, you can mix up the story like maybe you have chapters in the store. I don't know. You might have chapters in the story and then depending on how you arrange it, then it's not the same story. (.) It reminds me of, I don't know if you guys know this, it's uhm. I think it's a Netflix game where basically you have a. (.)",
#  '00:20:39 Xavier',
#  "Like the main theme is a Princess, and then there's a story. And so you have the first thing. The first story is like a storyboard where you have elements that you can move around.",
#  '00:20:49 Xavier',
#  'And then you need to you need something very specific to happen. So for example, the Prince needs to die, but the Princess needs to be alive. And then you just move around the storyboard and based on how you move it around.',
#  '00:21:01 Xavier',
#  'The.',
#  '00:21:01 Xavier',
#  "Chick like the the story changes or for example like there's an apple and maybe the apple is not poisoned at first but.",
#  '00:21:09 Xavier',
#  'So then if you have the witch poison the apple and then the apple being given to the Princess and the Princess gives it to the Prince and the Prince eats.',
#  '00:21:18 Xavier',
#  'The apple well.',
#  '00:21:19 Xavier',
#  "The last thing is the Prince is dead and the Princess is alive, and then you've reached your goal.",
#  '00:21:24 Xavier',
#  'So maybe you could move around like you.',
#  '00:21:26 Xavier',
#  'Could make a story on.',
#  '00:21:27 Xavier',
#  'The post-it that you then just move around and then it gives you a different conclusion to the story.',
#  '00:21:33 Julia',
#  'There was a thing one Netflix series who had, like, different starting on the on the colours and or that you had like maybe saw first episode 3.',
#  '00:21:37 Xavier',
#  'Yes.',
#  '00:21:41 Xavier',
#  'The highest',
#  '00:21:43 Julia',
#  'Yeah, yeah, yeah.',
#  '00:21:46 Xavier',
#  'Kaleidoscope.',
#  '00:21:48 Stan',
#  "Haven't seen that one.",
#  '00:21:49 Xavier',
#  'It’s a nice one.',
#  '00:21:50 Julia',
#  "It's it's nice, yeah.",
#  '00:21:51 Stan',
#  'Like sort of like choose your own adventure, that kind of stuff or.',
#  '00:21:54 Xavier',
#  "No, it's like basically every episode, except the final one could be watched in any order.",
#  '00:22:02 Stan',
#  'Hmm.',
#  '00:22:03 Xavier',
#  "Like, it's basically each episode is a different part of the story, and it doesn't matter which part you're looking at.",
#  '00:22:10 Julia',
#  'So in theory you could click.',
#  '00:22:10 Xavier',
#  "There's like no right order.",
#  '00:22:13 Julia',
#  'So basically you could decide on this on your story.',
#  '00:22:15 Xavier',
#  'And everyone on Netflix got a different order, except the final one was always the last episode. But all the other ones you could just watch however you want.',
#  '00:22:22 Stan',
#  'Cool.',
#  '00:22:22 Xavier',
#  'And then I feel like it would. It was nice and creative cuz it got you to view the story very differently.',
#  '00:22:31 Stan',
#  'Hmm.',
#  '00:22:32 Xavier',
#  "Because, like maybe at the beginning, you hate a character because you don't understand how they're like, why they're acting like that, but someone else that saw another chapter before was like, well, I get why he's doing that because he's had this in his past or whatever. So.",
#  '00:22:47 Xavier',
#  'And so, yeah, maybe the the idea of using that in the post it where you can just rearrange things and it kind of means a different thing might be interesting.',
#  '00:22:56 Julia',
#  'Another idea that pops into my mind is that we just make and as long as like a Slinger.',
#  '00:23:03 Xavier',
#  'Aligned.',
#  '00:23:06 Julia',
#  'Like just just to.',
#  '00:23:09 Julia',
#  'Put it over like the balcony and just see if we can reach the OR reach the the other side.',
#  '00:23:14 Xavier',
#  'Other side.',
#  '00:23:16 Xavier',
#  'A bridge a post it bridge',
#  '00:23:18 Julia',
#  'A post itbridge Yeah.',
#  '00:23:16 Stan',
#  "It's also quite fun.",
#  '00:23:19 Stan',
#  "I love that it's like some of them are very abstract and some of them are just let's do something cool.(laugh)(.)",
#  '00:23:27 Xavier',
#  "We could make uh. Yeah, we could make uh. (.) A model of the faculty or something. I don't know. You could do a lot of things if you fold them. (.) It doesn't use the aspect of like the reusability and the stickiness of the of the notes. But it would be a fun thing to.",
#  '00:23:34 Julia',
#  "MHM. You could say. if we’d say if it's a measurement tool, then you can. (everyone laughs)",
#  '00:23:48 Xavier',
#  'How long is the faculty in sticky notes?',
#  '00:23:51 Julia',
#  'Yeah, yeah and then how long am I and how long is the table?',
#  '00:23:53 Stan',
#  "Yeah. Yeah. Measure everything in sticky notes. That's quite funny. That's yeah. Yeah.",
#  '00:23:56 Xavier',
#  "Honestly, that would be funny. You just align sticky notes just to figure out how long things are. It's a new measurement concept.(.)",
#  '00:24:04 Xavier',
#  'Like that, you know how many sticky, sticky notepads you can',
#  '00:24:07 Stan',
#  'Yeah.',
#  '00:24:08 Xavier',
#  'Lay flat on the surface.',
#  '00:24:09 Stan',
#  'Yeah, you know, do you know the joke with the bananas? Like how everything is in bananas.',
#  '00:24:08 Everyone',
#  'No',
#  '00:24:09 Stan',
#  "There's like a whole Internet meme about measuring things with bananas, because I think it started with like marketplaces and people didn't have measurement tapes and wanted to show how big things are and they just laid a banana right next to it for scale, banana for scale. So we can do something like that.",
#  '00:24:31 Xavier',
#  'Post it for scale I mean not post it for scale, literally post it measurement.',
#  '00:24:35 Stan',
#  'Yeah, but then also like the measuring the surface, for example of IDE or the length and the width offices sizes that would be really funny.',
#  '00:24:44 Xavier',
#  'But maybe not the whole idea faculty, because that would take a lot of Post it playing but.',
#  '00:24:49 Stan',
#  'Ohh would be funny to just film someone like doing. (laugh)',
#  '00:24:52 Julia',
#  "We have 100 and the measurements are 76. We probably have like an overlap of five, let's say 70. We can do.",
#  '00:25:01 Xavier',
#  '70  times a  hundred that is not going to get us far.',
#  '00:25:04 Julia',
#  'No.',
#  '00:25:04 Xavier',
#  'That is 70, I mean, OK, 70 metres. Wait. What? No. Yes.(.)',
#  '00:25:12 Xavier',
#  'No, 7 centimetres times a hunderd, no 7 metres.',
#  '00:25:14 Julia',
#  'Zevenhonderd, 7 metres.',
#  '00:25:17 Xavier',
#  'OK.(.)',
#  '00:25:20 Stan',
#  "I think that's doable.",
#  '00:25:21 Xavier',
#  'The whole faculty?',
#  '00:25:23 Julia',
#  "No, we don't. Why should we do the whole faculity?",
#  '00:25:23 Stan',
#  'No, no, no, no.',
#  '00:25:25 Julia',
#  'Why did you come up with that? (laugh)',
#  '00:25:26 Xavier',
#  'I don’t know.',
#  '00:25:27 Stan',
#  'But we could also, just go outside and do like length width. And just film someone in like (.) 5 times speed doing that.',
#  '00:25:34 Xavier',
#  'Just think what? So what would the idea would we layout the posted first have themas a line and then use that line to measure or?',
#  '00:25:39 Speaker 7',
#  'Have.',
#  '00:25:42 Stan',
#  'Yes. (laugh)',
#  '00:25:45 Xavier',
#  'By one or do you just stick post its and measure them one by one? You stick first  and then just move them around.',
#  '00:25:48 Julia',
#  "But one of the nice things is that you don't have one measurement thing. We don't have to put them all together. We can just say. You can also only use 10 to measure something. You can use 50 or.",
#  '00:25:58 Xavier',
#  'Yes. Yeah, true. You could have different dimensions.',
#  '00:26:01 Julia',
#  "Yeah, that's actually.",
#  '00:26:01 Xavier',
#  'This is a 10 posted length. This Is a 20 posted length.',
#  '00:26:04 Julia',
#  'Exactly. Yeah.',
#  '00:26:05 Stan',
#  "Or we maybe it's nicer to do something inside and then just for example, for this space just have measure this space and then put the post it on the door. Like this space is so many posts in surface and then for example do the same with the doors like. This thing is so many post its in heght and go on and on.",
#  '00:26:27 Xavier',
#  'This door is uh (.) This x post its by y post its. this room is x its by y post its and then you just you can map out the room with post its.',
#  '00:26:37 Stan',
#  'Can fit X amount of post its on the walls in this. Room or something like that. (..)',
#  '00:26:43 Julia',
#  "So it's a conceptual measure, new.",
#  '00:26:46 Xavier',
#  "It's a new conceptual measuring tool, yes.",
#  '00:26:48 Stan',
#  "Yeah. And like, if there's like a 30 zone here, it's like your max speed limit. So many posts an hour. That's quite funny.",
#  '00:26:59 Julia',
#  'Hmm. (..)',
#  '00:27:01 Stan',
#  'I like this concept.',
#  '00:27:04 Xavier',
#  'Its a wild concept.',
#  '00:27:05 Julia',
#  'Rueben, what do you think? ( everyone laughs)',
#  '00:27:08 Xavier',
#  'Rueben’s lost it with our conceptual thinking.',
#  '00:27:10 Rueben',
#  'I mean, yeah, we can do it, I guess. (laugh)',
#  '00:27:14 Xavier',
#  'I mean.',
#  '00:27:15 Julia',
#  "Would you like it or do you have something you don't like about it?",
#  '00:27:19 Rueben',
#  "I'm open for it, I just don't know what. What exactly are you going to measure?",
#  '00:27:24 Xavier',
#  'Whatever you want.',
#  '00:27:25 Rueben',
#  'OK.',
#  '00:27:26 Stan',
#  'What do you want to measure, Rueben?',
#  '00:27:26 Julia',
#  'You can measure your own heights.',
#  '00:27:27 Xavier',
#  'Measure. We could do ergonomics measurements with Post-its.',
#  '00:27:33 Xavier',
#  'We could do, yeah. Waist circumference with post its and height.',
#  '00:27:41',
#  'Yeah.',
#  '00:27:41 Xavier',
#  "It's just it's so open. We can do a big it's. Just because it's so open, we can do whatever we want with this so.",
#  '00:27:46 Rueben',
#  'Yeah.',
#  '00:27:50 Stan',
#  'Maybe just should we just write some things down that we could measure and see whether it has any potential?',
#  '00:27:57 Xavier',
#  'Yeah, we can try to explore It a bit more, yeah.',
#  '00:27:59 Julia',
#  "I if we are gonna think practical, I only think it's nice if we in the video nothing but we do it just like three things or something. For instance, I like the one you said with speed. Can we do it like that? Measure. A person's height and then also measure something really big. For instance, the length of the Hall. That's maybe funny.",
#  '00:28:23 Xavier',
#  'Yeah.',
#  '00:28:25 Xavier',
#  'So that could be one of the concepts I really liked our brain concept at the beginning, the moving puzzle or like the escape the. thing of like. You just have a puzzle and then you move things around and you see if you can still solve it because that really implements the the idea of Post-its can move around. They just stick to whatever you want and Really brings out that creative aspect.',
#  '00:28:48 Julia',
#  'But I like about it that one as well is that you can do it with multiple people, because I also always enjoy because with working with the sticky notes is that you can write something down, put it there and then I say Oh no, I think it should be there.',
#  '00:28:59 Xavier',
#  "So basically everyone's trying to solve the puzzle and everyone's destroying everyone else's puzzle at the same time. You just keep moving the brain around and you're trying to get to the you all. Yeah. I mean, you could all have different beginnings. Yeah. And then you're all trying to get to the end, and then you just have to move post its  around to get to the.end.",
#  '00:29:18 Xavier',
#  'And someone can.',
#  '00:29:19 Julia',
#  "Or you can only move one posted at a time and then we have to do it In a specific order, I don't know.",
#  '00:29:23 Xavier',
#  'Yeah, that it. It could be a game out of like, get first to the end line and you just move around. Post its to either you be able to go forward or prevent someone from going forward.',
#  '00:29:35 Julia',
#  'Are you familiar with like the cooperative games? So we play a game, but we all want the same end goal. We all want to win as a team.',
#  '00:29:43 Xavier',
#  'Yeah.',
#  '00:29:44 Julia',
#  'I feel like this could be something like that, but it could be also be something individual to block someone else and.',
#  '00:29:47',
#  'No, but how would you make it a cooperative?',
#  '00:29:51 Julia',
#  "To say that we play with the four of us, we have one starting point and one endpoint, and if one people can only move one sticky note at a time, then we have this have the same goal. We want to go to the end together. And then we have to talk about Ohh, which one should I do next? But yeah, maybe you are not allowed to speak. I don't know. Yeah",
#  '00:30:07 Xavier',
#  'Oh. And and maybe, I mean you could combine that as in everyone needs to get to the end at the same like, maybe everyone needs to get to the end at the same time or something like that?',
#  '00:30:22 Julia',
#  'Yeah. You just have one player.',
#  '00:30:25 Xavier',
#  "And oh, you just have one player. It's like the when somebody starts a sentence and then you pass on the thing and then the person, yeah.",
#  '00:30:32 Julia',
#  'Maybe, maybe.',
#  '00:30:31 Xavier',
#  'No, But I still the like the concept',
#  '00:30:33 Stan',
#  "And you could still have one of the of the participants that's trying to obstruct you. That could also be fun.",
#  '00:30:43 Xavier',
#  'Or just one participant. That knows where the end is.',
#  '00:30:46 Julia',
#  "Oh., that's fun. Everyone gets a different piece of information.",
#  '00:30:49 Xavier',
#  'Yeah, just everyone knows something different. Like maybe you have end and some like checkpoints. Or something like that then.',
#  '00:30:59 Julia',
#  'Yeah, yeah, yeah. And if you missed maybe 1 checkpoints.',
#  '00:31:00 Xavier',
#  'You need to go through every checkpoint and get.',
#  '00:31:02 Xavier',
#  "To the end and then Like probably chaos ensues and that one would really work well if you're not allowed to talk.",
#  '00:31:09 Stan',
#  'Ohh yeah.(..)',
#  '00:31:12 Julia',
#  'Do we want to work towards a game or a bit more education oriented?',
#  '00:31:17 Xavier',
#  "I mean, technically it's this would be a game and educational it. It learns to, it helps you work in a team. With zero communication.",
#  '00:31:25 Julia',
#  'Then my more specific question is, do we want it to be design oriented design, design education oriented?',
#  '00:31:33 Xavier',
#  'It not being design education either.',
#  '00:31:34 Stan',
#  'Me neither(.)',
#  '00:31:35 Julia',
#  'Rueben?(.)',
#  '00:31:38 Rueben',
#  "I also don't mind it.",
#  '00:31:40 Julia',
#  "Then no. I then I think it's nice that we check that and then we just move forward to game. I love games so.",
#  '00:31:46 Xavier',
#  'Yeah. Perfect.(..)',
#  '00:31:50 Stan',
#  "Maybe we should. We can also use that board to figure out how this would look. I have some whiteboard markers would use let's see if I can get there.",
#  '00:32:00 Xavier',
#  'How’s the recording looking. (..)',
#  '00:32:04 Xavier',
#  'Is there now, no wrong button. Is the phone dead? (laugh)Not a good start. (..)',
#  '00:32:10 Xavier',
#  'Um yeah, so that could be a second concept. I still like the the post it tape measurement thing just as a wanky like a weird way of measuring things. (.)',
#  '00:32:16 Julia',
#  'Yeah.',
#  '00:32:21 Julia',
#  'Yeah, I like it too.',
#  '00:32:24 Xavier',
#  "But yeah, so that's two ideas, and let's see what. Let's try and see maybe how to work out.",
#  '00:32:31 Julia',
#  "I'm also thinking about the video. Should we maybe umh?(.)",
#  '00:32:36 Xavier',
#  "I mean the video in one case would just be the how people, how like you might want to, make an instructional video on how to measure things with the post it.And so then you we do like, how would you measure someone with a post it and then we show a funny way of measuring someone with a post it and then how do you measure the length of a hallway with the post it? And then we just have like, segments that just show this is how you do it. It's just like kind of an instructional video of a very weird concept of measuring stuff with post its..",
#  '00:33:01 Julia',
#  'Hmm.',
#  '00:33:08 Julia',
#  "Hmm, but should we? I thought that the video was should be like one minute about explaining how we come up with what we came up with. And then the second minute should be about how it's. But that's how I interpreted.",
#  '00:33:05 Xavier',
#  'And then.',
#  '00:33:20 Rueben',
#  'its only outcome of the process.',
#  '00:33:21 Xavier',
#  'Yeah, outcome.',
#  '00:33:21 Julia',
#  "Ohh we just have to. OK, that's nice.",
#  '00:33:24 Xavier',
#  'So then yeah, for the post it measurement, it would might just be. Like, Oh no.',
#  '00:33:29 Xavier',
#  'Is it? That is sad.',
#  '00:33:37 Julia',
#  'Is there like a cleaner?(.)',
#  '00:33:46 Stan',
#  'You can also just do it on the wall.(laugh)',
#  '00:33:54 Stan',
#  'You were talking about?',
#  '00:33:55 Xavier',
#  "Yeah. So we were talking about what the video might look like for both of these. So for the the post it, we might just make a instructional video of how to measure with Post-its. So just like you put a title and say like, here's how you measure someone posted, and then we just have a fast video of someone sticking Post-its next to someone. And then here's how you measure a hall with Post-its and you show that.",
#  '00:34:18 Xavier',
#  'And then for the for the the game. Maybe just you have a time lapse of us playing the game or something. That could be a nice way to to show the the the concept.',
#  'Mm-hmm.',
#  'But yeah (.) and do we want to try and find a third concept and then just pick one and then flesh it out more based on which one we like the most?',
#  '00:34:43 Julia',
#  'Yeah, I think we have like multiple concepts, but these are the most 2 concrete I think.',
#  '00:34:45 Rueben',
#  'Yeah.',
#  '00:34:48 Xavier',
#  'Do we want to try and make another one a bit more concrete, or do you just want to pick out one out of the two we have right now?',
#  '00:34:53 Stan',
#  "I'm fine with picking one of the two?",
#  '00:34:54 Julia',
#  'Yeah, me too.',
#  '00:34:56 Xavier',
#  'How do we want to proceed with the the vote?',
#  '00:35:02 Rueben',
#  'Hmm.',
#  '00:35:03 Julia',
#  'I get the most enthusiastic about the game. What about you guys?',
#  '00:35:08 Stan',
#  "I'm neutral.",
#  '00:35:12 Xavier',
#  'The measuring is probably going to be easier to realise.',
#  '00:35:17 Xavier',
#  'The mine puzzle whatever is going to be trickier, but might be more fun in the end.',
#  '00:35:26 Julia',
#  'What do you what do you have a preference? If you listen to your guts?',
#  '00:35:32 Xavier',
#  "The puzzle could be a fun challenge. I feel like. We have to make sure we don't get lost in making it overly complex.",
#  '00:35:40 Julia',
#  'No. Maybe only set three base rules. Whatever max 5 and then. (.)',
#  '00:35:46 Xavier',
#  'And then the basic mechanics. Yeah, yeah. The puzzle could be fun. Rueben?',
#  '00:35:51 Rueben',
#  'My preference goes to the puzzle as well. I think the measurement one is Funny, but',
#  '00:35:57 Xavier',
#  "It's like a Joke.",
#  '00:35:59 Rueben',
#  "Yeah, but more than that I don't know. For the video. (.)",
#  '00:36:002 Stan',
#  'Yeah. Yeah. OK. OK, cool.',
#  '00:36:03 Xavier',
#  'So puzzle it is. (..)',
#  '00:36:10 Xavier',
#  'Well then maybe.',
#  '00:36:10 Julia',
#  'Should we just say quick for the time should we aim for Max and hour.',
#  '00:36:16 Julia',
#  'Just to',
#  '00:36:16 Xavier',
#  "I'm I'm free till 45.",
#  '00:36:18 Julia',
#  'Yeah, me too. But just for ourselves. What do we want to have a goal or?',
#  '00:36:21 Stan',
#  'Yeah, yeah, yeah.',
#  '00:36:23 Xavier',
#  'I mean, I think for the next, yeah, maybe for the next, maybe you can take a quick break. For some water and then for the next 20 minutes, we just figure out all the rules and how the game is going to work. And then we take probably, I hope not more than 10 minutes playing the game and see if it works out.',
#  '00:36:39 Julia',
#  'Yeah, and take the video and then yeah, so at the end of the day, we are done with the recording and then someone maybe can edit it.',
#  '00:36:46 Julia',
#  'And then we.',
#  '00:36:46 Stan',
#  'Yeah, yeah.',
#  '00:36:47 Julia',
#  "Don't have to spend much.",
#  '00:36:48 Stan',
#  'Time sounds.',
#  '00:36:48 Xavier',
#  "I'm good with that because I have.(.)",
#  '00:36:50 Xavier',
#  'A deadline from last quarter that is has been postponed for me to the end of the weekend, so I need to make sure I Have time tomorrow to work on that. So yeah, if we can finish by today. That would be Perfect.',
#  '00:37:02 Julia',
#  'Oh, lets do a small water break, yeah.',
#  '00:37:03 Xavier',
#  'OK, quick.',
#  '00:37:10 Stan',
#  'Or do we want to record our break?',
#  '00:37:14 Xavier',
#  'Yeah.',
#  '00:37:15 Stan',
#  "I'll take it with me.(..)",
#  '00:37:21 Xavier',
#  "I mean, if we have a post that's left, we can always stick some motivational messages, some other faculty.",
#  '00:37:30 Speaker 6',
#  'As a free.',
#  '00:37:32 Stan',
#  'Yeah.',
#  '00:37:34 Xavier',
#  'As a free, enjoy your day message. (...)',
#  '00:37:46 Julia',
#  "Escpecially with the electives you become very aware of the different ways of thinking between the different master tracks I feel like. (..) Because I do think there are some specifics of A SPD, IPD or DFI student. And I always. Like I don't want to stereotype  with that, but I see some patterns coming back.",
#  '00:38:12 Xavier',
#  "I'm now I'm curious what are? The patterns you see.",
#  '00:38:20 Stan',
#  'Ooh, be careful. (everyone laughs)',
#  '00:38:23 Xavier',
#  'Cold sweat. What did I could just get myself.',
#  '00:38:26 Julia',
#  "Into I think specifically last quarter I worked with all DFI group and and then it was a bit more or how do you say I'm quite practical we just say like, OK, as an SPD student we just state the goal and.",
#  '00:38:31 Xavier',
#  'MHM.',
#  '00:38:40 Julia',
#  "To find a way to work with and D5 students are person, so really only align like how? How are we feeling today? It's not really bad to come 5 minutes late and also a bit more fuzzy conversation instead of setting something like this, we talked about this and this is the goal and they are a bit like OK, we're going to explore that a little bit and we're going to explore that a little bit. And then in the end they have a very clear picture of what we're going to do and I was totally lost. So there was very interesting to see that.",
#  '00:39:09 Stan',
#  'Ohh cool.',
#  '00:39:10 Xavier',
#  'Yeah. Yeah, so they use chaos to then get organised.',
#  '00:39:14 Julia',
#  "Exactly they're actually very good in creating structure from the chaos and I thought as an SPD student I was very good at that as well. But then only if I use the structure within everything I do.",
#  '00:39:24 Stan',
#  'Yeah.',
#  '00:39:24 Xavier',
#  'Whereas them is just pure chaos at the beginning and then it ends up being something structured.',
#  '00:39:30 Julia',
#  'Exactly. And they were not stressed about it at all. And I was. (laugh)',
#  '00:39:33 Stan',
#  "Yeah, I also get really frustrated with that, but I also haven't really worked with DFI students, so maybe that's a good tip.",
#  '00:39:39 Xavier',
#  "No, but even like I was doing the the generative AI. Like at the beginning are tool or concept was going everywhere. Like when I mean, everywhere since we just had so many ideas and so, so much complexity. But we are all IPD students. It's just like two of them are just have like 30 ideas a minute. And so when they're trying to put all 30 ideas a minute inside the project, you're like this is going to start getting tricky at some point. So in the end, we just, we didn't even, I mean we had a solution, but I feel like if we had focused more at the beginning, we Would have gotten further.",
#  '00:40:15 Stan',
#  'Yeah.',
#  '00:40:15 Xavier',
#  'So it just depends on how much how far you want to go into a solution. And how far you want to explore the possible solution space so. (..)',
#  '00:40:25 Julia',
#  'Yeah, interesting.',
#  '00:40:27 Xavier',
#  'Did you do a lot of projects already with IPd students?',
#  '00:40:29 Julia',
#  "Yeah. Also now with Build your start up and also like with with you you like or the like with within the Build your start up group, the two SPD persons me and Sam can really have a long discussion. And then afterwards we are quite aligned and then it's like OK, let's do it. And the IPD students are after 10 minutes, there are lost, they just cannot have their attention span just to talk about conceptual things, they really tend to :I need to have like a specific task where I can work on and otherwise I don't like it?(.) And also you were quite like, OK, where do we want to go to instead of just letting that all go a little bit and just be creative, let's see where it goes. So that's interesting.",
#  '00:41:12 Rueben',
#  'Hmm.',
#  '00:41:16 Stan',
#  'Yeah, very concrete, yeah.',
#  '00:41:18 Stan',
#  'I totally agree with that. Definitely, yeah.',
#  '00:41:21 Xavier',
#  "Yeah, I mean, I don't mind. Yeah, I feel I mean, but maybe it's an excuse. I feel like I'm more concrete also because we have to hand in something at the end and I feel like if we're not concrete, I mean I am able to just let loose. But then if I let loose, I'm not sure I'm going to get to a final solution. Yeah. So I tried to. I tried to prefer to like, be concrete from the start because. (.) And then you have the space where you can let loose. But if you're like letting loose all the time, I feel like I'm never going to get to the end where I have something because it might be like: Oh Times over? And then you're. Oh, but I haven't even decided what my final concept is.",
#  '00:41:58 Stan',
#  "It's always about finding the balance. Yeah, because letting loose is very important. Also, to get more creative, definitely. But I've also had a lot of experience with people being a bit too creative and just being all over the place, and I had to be the one that was like guys. We need to finish something at the end of this day. Come on, let's go. So yeah, there's definitely a balance. Yeah.",
#  '00:42:22 Julia',
#  "And one thing that also is returning thing with IPD students is that they like to think in options. So just how you did now like we can do this or we can do that. So you're not making directly a decision or articulating what you want because I think I believe students are very like OK, we need to make group decisions. And by doing like giving the options to the group, you can make like a nice “overwogen” like like, like over like consider decision instead of taking already. OK, I think we should do this.",
#  '00:42:46 Stan',
#  'Considered.',
#  '00:42:52 Julia',
#  'This yeah.',
#  '00:42:57 Xavier',
#  "Yeah, fair enough. I I just feel like if I make. I mean when you say we should, I think we or we should do this. It feels like you're taking the the decision for the group, which is weird for me to like.",
#  '00:43:07 Julia',
#  'If you could give good, good, give good argumentation, and I could always give a response.',
#  '00:43:11 Stan',
#  "True true thing. Maybe it's also a bit of a touch. Directness, like, not necessarily meaning that your opinion is the best opinion, but saying it, that's yeah.",
#  '00:43:23 Xavier',
#  "I mean, I so I'm very direct with things.",
#  '00:43:26 Xavier',
#  'But with that. No. Yeah.',
#  '00:43:28 Julia',
#  'I used to be a lot like, I used to do a lot also giving 2 possibilities to people because I always thought it it helps but it it made me forget sometimes to articulate my own…',
#  '00:43:40 Xavier',
#  "The thing is, I'm not afraid to articulate my own opinion, and I'm not afraid when people like disagree with me, it's just when you're working with international students they don't tend to like, there's definitely some cultures where you're not meant to like if your opinion is not asked, you will not give your opinion. So that's why I've in London, there's a lot of I feel like, especially Asian cultures, they tend to be more on their side. And if you don't give them the space to tell them please contradict me. Please give me your ideas. They are. They're here to stay back and not say anything about it. So that's why I feel like maybe that's why I've started doing more like. And what do you think? Because if not, you don't get feedback. But yeah that definitely if somebody's like. Oh, I really like that. I'm like, no, I don't like that. I just tell them like, no I don't.",
#  '00:44:21 Julia',
#  "Yeah, but it's it's also a good thing, yeah.",
#  '00:44:29 Xavier',
#  "Like I remember for AED last year, which is of course well, yeah. And like I had initially made a group and we had to all pick like the topics we wanted to do. And I was like not agreeing with any of the like, the priority list they were putting together. I was like, no, I'm sorry guys, but I'm going to have to ditch this group. I like you guys, but I'm going to have to make my own choices because if I'm going to be stuck with what you guys like. For the whole semester, it's not going to work out so.",
#  '00:44:58 Stan',
#  'That is good right? To be honest about that.',
#  '00:44:59 Xavier',
#  'Yes. Yeah.',
#  '00:45:01 Stan',
#  'Would be terrible to do your entire AED.',
#  '00:45:03 Xavier',
#  "Talking about what you don't like.Be miserable because you don't like what you're doing. Yeah.",
#  '00:45:06 Stan',
#  'Yeah, because to me (.) AED was is like the pinnacle of IPD in terms of the project, I love the project.',
#  '00:45:10 Xavier',
#  'What did you have?',
#  '00:45:17 Stan',
#  'I had a really cool assignment where we needed to make muffler muffles for police dogs dashboard actually.',
#  '00:45:23 Julia',
#  'Oh cool.',
#  '00:45:24 Xavier',
#  'Where you with Marijn?',
#  '00:45:27 Stan',
#  'No, no, that was the other group there were two teams.',
#  ...]

# %%
print("Remove last item if it is incomplete.")
print('--------------------------- LAST 4 LINES ---------------------------')
for t in transcript_list[-4:] :
    print(t)
print('-------------------------------- END -------------------------------')

# Uncomment and re-run this cell if the last line is found to be incomplete
# if type(transcript_list[-1]) == list :
    # transcript_list.pop()
# Out:
# Remove last item if it is incomplete.
# --------------------------- LAST 4 LINES ---------------------------
# 01:41:37 Xavier
# Julia is going to be confused, but.
# 01:41:47 Stan
# There you go. OK, now I can end the recording
# -------------------------------- END -------------------------------

# %% [markdown]
# ### Convert into DataFrame
# Conver the list with successive items being `['timestamp', 'speaker]` and `'utterance'` items into a DataFrame

# %%
transcript_triad = []
for ind, line in enumerate(transcript_list) :
    if ind % 2 == 0 and ind+1 < len(transcript_list):
        # these are speaker/timestamp lines
        if line[0].isdigit() :
            # the start is a timestamp
            timestamp = line.split(' ')[0]
            speaker = ' '.join(line.split(' ')[1:])
            utterance = transcript_list[ind+1]
        else :
        # The line contains speaker but not timestamps 
            timestamp = ''
            speaker = line
            if len(line.split(' ')) > 2 :
                print("*****************************************")
                print("Problem found!")
                print(transcript_list[ind-3:ind+1])
                print(ind)
                print("*****************************************")
                break
            utterance = transcript_list[ind+1]
        turn_data = { 'timestamp' : timestamp,
                      'speaker'   : speaker,
                      'utterance' : utterance
                    }
        transcript_triad.append(turn_data)

# %%
# print(transcript_triad)
df = pd.DataFrame(transcript_triad)
df.sample(5)
# Out:
#     timestamp speaker                                          utterance
# 948  01:22:51  Xavier                    I don't know, you choose, here.
# 163  00:13:45   Julia                                        Yeah, true.
# 221  00:18:38    Stan  And then maybe write down it like pass this on...
# 190  00:15:20    Stan                          Yeah, that's interesting.
# 496  00:45:17    Stan  I had a really cool assignment where we needed...

# %% [markdown]
# ### Save DataFrame
# Because this involves text which can have punctuations including commas and semicolons, a CSV file is not recommended. Instead, save it as an excel file.

# %%
excel_name = transcript_path.split(".docx")[0] + ".xlsx"
df.to_excel(excel_name)
print("File saved to:", excel_name)
# Out:
# File saved to: data/xavier-transcript.xlsx
